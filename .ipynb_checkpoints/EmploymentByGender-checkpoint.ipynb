# %% [markdown]
# # Employment by Gender at UFRN

# %%
import pandas as pd
import numpy as np
from bokeh.charts import Donut, BoxPlot, show, output_notebook
from bokeh.layouts import row

df = pd.read_csv("csv/serversTreatedWithGender.csv")

# %%
genderDF = df
genderDF.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  \
# 0           0             0               2
# 1           1             1               3
# 2           2             2               5
# 3           3             3               6
# 4           4             4               7
#
#                                          name     money  \
# 0                    adailton garcia da silva   7464.42
# 1                acacia jessica maia de moura   6580.61
# 2            adam rafael goncalves cavalcante   2905.70
# 3  abrahao sanderson nunes fernandes da silva  11085.51
# 4                       adeilde lima da silva   4538.01
#
#                                post class  level  \
# 0           TECNICO EM AGROPECUARIA     D    NaN
# 1                 ASSISTENTE SOCIAL     E    NaN
# 2       ASSISTENTE EM ADMINISTRACAO     D    NaN
# 3  PROFESSOR DO MAGISTERIO SUPERIOR     6  600.0
# 4              AUX EM ADMINISTRACAO     C    NaN
#
#                                   org gender
# 0  ESCOLA AGRICOLA DE JUNDIAI - UAECA      M
# 1  ESCOLA AGRICOLA DE JUNDIAI - UAECA      F
# 2         DEPARTAMENTO DE ESTATISTICA      M
# 3      DEPARTAMENTO DE HISTORIA-CERES      M
# 4                ADMINISTRACAO DO CCS      F

# %% [markdown]
# ## Overall Salary Distribution and Participation by Gender

# %%
def showStats(data):
    femaleDF = data[data.gender == 'F']
    maleDF = data[data.gender == 'M']
    print(str(len(data)) + " employees:")
    print("Males: " + str((len(maleDF)/len(data))*100) 
          + "%\tFemales: " + str((len(femaleDF)/len(data))*100) + "%")

    print("\nOverall salary:\nMedian: " + str(data['money'].median()) + "\tMean:" + str(data['money'].mean()))
    print("Male salary:\nMedian: " + str(maleDF['money'].median()) 
          + "\tMean:" + str(maleDF['money'].mean()))
    print("Female salary:\nMedian: " + str(femaleDF['money'].median())
          + "\tMean:" + str(femaleDF['money'].mean()))

    boxPlot = BoxPlot(data, values='money', label='gender',
                title="Salary Distribution by Gender", color = 'gender', plot_width=300, plot_height=500)
    donut = Donut(data, label=['gender'], title="Female and Male Servers", plot_width=500, plot_height=500)
    output_notebook()
    show(row([boxPlot, donut]))

showStats(genderDF)
# Out:
# 11298 employees:
# Males: 52.566825986900334%	Females: 47.362365020357586%
#
# Overall salary:
# Median: 7967.9	Mean:9260.355903699743
# Male salary:
# Median: 7648.76	Mean:9284.776038053447
# Female salary:
# Median: 8200.45	Mean:9239.159564567284
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="dd89aa13-50b8-4492-a3e5-2598e24972f9">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1183e9d3-f381-427f-836e-20e58484e3ca"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("1183e9d3-f381-427f-836e-20e58484e3ca");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1183e9d3-f381-427f-836e-20e58484e3ca");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1183e9d3-f381-427f-836e-20e58484e3ca' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d32ac14c-33d4-447c-936a-9fd7b8943194":{"roots":{"references":[{"attributes":{"data_source":{"id":"116052e6-16e2-4289-b5fe-59f7372ab42b","type":"ColumnDataSource"},"glyph":{"id":"c2c13d96-20f1-4bfc-b09c-6be82ef21db2","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"cfa582da-c9f5-4942-b15b-f09c7f78984c","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"301e6794-f5a2-4d95-8b3d-8af8d1afb4d3","type":"ColumnDataSource"},"glyph":{"id":"a763f576-b3e2-424b-b749-1d6f53369b0a","type":"Segment"},"hover_glyph":null,"muted_glyph":null},"id":"4e83351e-2226-46de-9f00-2050456a8f5f","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"5c77dd2e-88ca-4735-8de1-517040087347","type":"ColumnDataSource"},"glyph":{"id":"d56d3c4c-dfe2-473c-9ee1-2cf55d7884de","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"f8b71f41-7ab1-4bec-835f-760bd026474a","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"gender":"M"}],"color":["#5ab738"],"fill_alpha":[0.8],"gender":["M"],"height":[4700.275],"label":[{"gender":"M"}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["M"],"y":[9998.8975]}},"id":"d3a9f8d1-344b-4d51-8bdc-d7652c776d3a","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"cecf4e73-1bc1-440b-ad5a-3db3079fb4b4","type":"ColumnDataSource"},"glyph":{"id":"88da58ac-9c22-493e-bdb0-d074f5ff544c","type":"Segment"},"hover_glyph":null,"muted_glyph":null},"id":"a2281e0b-89de-446d-bbcd-11bedea8d236","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"571c286e-77c7-4ba8-a2b2-2226f6dd2405","subtype":"Chart","type":"Plot"},"ticker":{"id":"777a357d-7d18-48e5-8a49-838e500b64ea","type":"BasicTicker"}},"id":"471f9077-cd22-4f5c-aa58-9e9fd0469b78","type":"Grid"},{"attributes":{"data_source":{"id":"d3a9f8d1-344b-4d51-8bdc-d7652c776d3a","type":"ColumnDataSource"},"glyph":{"id":"56981260-30b7-4a5e-bfd4-be1beebe752c","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"383bbd69-2c1f-4299-8b97-eb2bff8fafae","type":"GlyphRenderer"},{"attributes":{"label":{"value":"X"},"renderers":[{"id":"d748d8e6-3e26-4648-bdec-f55cd0561a7c","type":"GlyphRenderer"},{"id":"bff9a2d1-8bb6-4361-80bb-72ea9d7cd8f6","type":"GlyphRenderer"},{"id":"4e83351e-2226-46de-9f00-2050456a8f5f","type":"GlyphRenderer"}]},"id":"5d15e5ee-bf9a-4aae-8449-57437579d3fb","type":"LegendItem"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"88da58ac-9c22-493e-bdb0-d074f5ff544c","type":"Segment"},{"attributes":{"label":{"value":"M"},"renderers":[{"id":"9a89b01f-fbd1-4d4d-970c-2317ce2d1333","type":"GlyphRenderer"},{"id":"383bbd69-2c1f-4299-8b97-eb2bff8fafae","type":"GlyphRenderer"},{"id":"cfa582da-c9f5-4942-b15b-f09c7f78984c","type":"GlyphRenderer"},{"id":"445f4228-7bf1-4c13-b5b8-e81463c37f52","type":"GlyphRenderer"}]},"id":"e7661725-4ff7-417b-b822-d1d7a3e4b431","type":"LegendItem"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"56981260-30b7-4a5e-bfd4-be1beebe752c","type":"Rect"},{"attributes":{"items":[{"id":"e7661725-4ff7-417b-b822-d1d7a3e4b431","type":"LegendItem"},{"id":"ea85509a-9973-4981-aca7-0fad72ece8f5","type":"LegendItem"},{"id":"5d15e5ee-bf9a-4aae-8449-57437579d3fb","type":"LegendItem"}],"location":"top_left","plot":{"id":"571c286e-77c7-4ba8-a2b2-2226f6dd2405","subtype":"Chart","type":"Plot"}},"id":"2e7d9423-6b83-4879-8018-045997c51ae1","type":"Legend"},{"attributes":{"callback":null,"factors":["F","M","X"]},"id":"c7d2f026-ac35-49b9-8d00-b59f65ee8c26","type":"FactorRange"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"o ...

# %% [markdown]
# ### The Top 5%

# %%
top = 5
quantile = genderDF.money.quantile(1.0 - top/100)
print("Top " + str(top) + "% salary >= R$" + str(quantile))
topDF = genderDF[genderDF.money >= quantile]
showStats(topDF)
# Out:
# Top 5% salary >= R$19912.21
# 567 employees:
# Males: 63.49206349206349%	Females: 36.507936507936506%
#
# Overall salary:
# Median: 21865.1	Mean:24501.49500881834
# Male salary:
# Median: 22045.915	Mean:24416.29144444443
# Female salary:
# Median: 21845.12	Mean:24649.675120772925
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="263877e7-73d0-401a-a0eb-b3932f4d2307">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c6706bb4-c19b-40f9-86be-c58378248e0a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("c6706bb4-c19b-40f9-86be-c58378248e0a");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c6706bb4-c19b-40f9-86be-c58378248e0a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c6706bb4-c19b-40f9-86be-c58378248e0a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8aa12da2-cf13-455e-9f96-7ca60222effb":{"roots":{"references":[{"attributes":{"data_source":{"id":"f1176d09-7f93-4912-8347-5dde36baf19d","type":"ColumnDataSource"},"glyph":{"id":"1d2a0d45-9ddd-49a5-94aa-8751b057cd1a","type":"Text"},"hover_glyph":null,"muted_glyph":null},"id":"b6e7bc65-028f-40f6-b1eb-3c8ec5dbdf1a","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"2810b126-65b0-42af-a6ee-540f21b827a0","type":"BoxAnnotation"},{"attributes":{"axis_label":null,"formatter":{"id":"6e87bc96-f716-4576-a393-0320dab6d436","type":"BasicTickFormatter"},"plot":{"id":"331f259e-c619-4f58-ba76-1b1df0d24176","subtype":"Chart","type":"Plot"},"ticker":{"id":"249b68d9-a828-474a-ad3c-de0ddf4042b4","type":"BasicTicker"},"visible":false},"id":"07a3df13-07fc-4b03-b27a-5ab5c1635dca","type":"LinearAxis"},{"attributes":{"angle":{"field":"text_angle","units":"rad"},"text_align":"center","text_baseline":"middle","text_font_size":{"value":"10pt"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1d2a0d45-9ddd-49a5-94aa-8751b057cd1a","type":"Text"},{"attributes":{"callback":null,"end":1.6500000000000001,"start":-1.6500000000000001},"id":"75a40426-0833-418d-acea-53cb5d7f08a2","type":"Range1d"},{"attributes":{"axis_label":null,"formatter":{"id":"030541c9-4fa9-4612-95dc-b1bb13a7cdd9","type":"BasicTickFormatter"},"plot":{"id":"331f259e-c619-4f58-ba76-1b1df0d24176","subtype":"Chart","type":"Plot"},"ticker":{"id":"86d4a631-c253-4f9e-909c-06ddd01b7a29","type":"BasicTicker"},"visible":false},"id":"0fe26a04-4599-4edc-8dbb-fe0da0277069","type":"LinearAxis"},{"attributes":{"location":"top_left","plot":{"id":"331f259e-c619-4f58-ba76-1b1df0d24176","subtype":"Chart","type":"Plot"}},"id":"b9b81f53-ac82-481f-b49b-92be1551aaa7","type":"Legend"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"red"},"line_color":{"value":"red"},"size":{"units":"screen","value":5},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"283718d1-5ed2-44b6-8709-1e194b1e7980","type":"Circle"},{"attributes":{"data_source":{"id":"3b5cc1ed-9923-4571-a60a-00758df3a0f4","type":"ColumnDataSource"},"glyph":{"id":"283718d1-5ed2-44b6-8709-1e194b1e7980","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"7bb4d866-0549-43ae-8e06-ace08f571910","type":"GlyphRenderer"},{"attributes":{},"id":"6ad04e72-8138-414d-8ae2-57b1615ca8d2","type":"CategoricalTickFormatter"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"gender":"M"},{"gender":"M"},{"gender":"M"},{"gender":"M"},{"gender":"M"},{"gender":"M"},{"gender":"M"},{"gender":"M"},{"gender":"M"},{"gender":"M"},{"gender":"M"},{"gender":"M"},{"gender":"M"},{"gender":"M"},{"gender":"M"},{"gender":"M"},{"gender":"M"},{"gender":"M"},{"gender":"M"},{"gender":"M"},{"gender":"M"},{"gender":"M"},{"gender":"M"},{"gender":"M"},{"gender":"M"},{"gender":"M"},{"gender":"M"},{"gender":"M"}],"gender":["M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M"],"x_values":["M:0.5","M:0.5","M:0.5","M:0.5","M:0.5","M:0.5","M:0.5","M:0.5","M:0.5","M:0.5","M:0.5","M:0.5","M:0.5","M:0.5","M:0.5","M:0.5","M:0.5","M:0.5","M:0.5","M:0.5","M:0.5","M:0.5","M:0.5","M:0.5","M:0.5","M:0.5","M:0.5","M:0.5"],"y_values":{"__ndarray__":"","dtype":"float64","shape":[28]}}},"id":"3b5cc1ed-9923-4571-a60a-00758df3a0f4","type":"ColumnDataSource"},{"attributes":{"callbac ...
