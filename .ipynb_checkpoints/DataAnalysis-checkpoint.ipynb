# %% [markdown]
# ## Normalizing the names to lowercase ascii to maximize the matchings between names from the name list and server list, in case of differences in spelling and uppercase/lowercase

# %%
import unicodedata

#from https://stackoverflow.com/questions/517923/what-is-the-best-way-to-remove-accents-in-a-python-unicode-string
def remove_accents(input_str):
    nfkd_form = unicodedata.normalize('NFKD', input_str)
    return u"".join([c for c in nfkd_form if not unicodedata.combining(c)])

def toLowercaseASCII(inputStr):
    noAccents = remove_accents(inputStr)
    return noAccents.rstrip().lower()

# %% [markdown]
# ## Creating sets, with normalized content, for female and male names

# %%
femaleNames = set()
maleNames = set()

def isFemale(name):
    return (name in femaleNames)

def isMale(name):
    return (name in maleNames)

def knownName(name):
    return isFemale(name) or isMale(name)

def putLinesInSet(filePath, collection):
    lines = open(filePath)
    for line in lines:
        collection.add(toLowercaseASCII(line))
        
putLinesInSet("csv/maleNames.csv", maleNames)
putLinesInSet("csv/femaleNames.csv", femaleNames)
print("Male names: " + str(len(maleNames)))
print("Female names: " + str(len(femaleNames)))
print("Names for both genders: " + str(len(femaleNames.intersection(maleNames))))
print(maleNames)
# Out:
# Male names: 3786
# Female names: 2947
# Names for both genders: 0
# {'galvino', 'behael', 'nigel', 'zabulao', 'placidio', 'navito', 'arnolfo', 'gualtiero', 'junior', 'odaleia', 'edvino', 'rishon', 'souza', 'valfredo', 'caled', 'oquena', 'perez', 'erasmo', 'malaquias', 'bartolomeu', 'antonio', 'barac', 'henrique', 'ronei', 'naldo', 'montgomery', 'moacir', 'macario', 'ulric', 'ciaran', 'ulando', 'welles', 'laoconte', 'martino', 'deolindo', 'luiz gustavo', 'gedao', 'romao', 'zeferino', 'neville', 'jean', 'anteu', 'jarbas', 'ado', 'gregor', 'ebalo', 'alexander', 'arapua', 'baltasar', 'jorio', 'gamaliel', 'alfonso', 'luan', 'pitagoras', 'jose augusto', 'glaucio', 'berilio', 'oivario', 'carlindo', 'kanope', 'eulino', 'feliciano', 'naindi', 'remo', 'basilio', 'anderson', 'niall', 'otacilio', 'benedito', 'erardo', 'hermenegildo', 'lourival', 'lineu', 'lisarte', 'soares', 'wilton', 'bentes', 'kennedy', 'nemestrino', 'skipp', 'espartaco', 'eder', 'edwin', 'thomas', 'corinto', 'catreu', 'agilulfo', 'macrino', 'berardo', 'natividade', 'micajah', 'ubaldo', 'anco', 'xafik', 'eumenes', 'ryan', 'cesare', 'oseias', 'fontoura', 'solano', 'barcelos', 'lake', 'jose luis', 'fahir', 'geremaro', 'macunaima', 'assis', 'koni', 'regis', 'samson', 'ezio', 'flaminio', 'ireneu', 'pace', 'ebraim', 'adamantino', 'militao', 'alcino', 'javae', 'keenan', 'graciniato', 'majui', 'hermeto', 'murilo', 'scott', 'cleodoro', 'juvenal', 'himineu', 'jorge luiz', 'bacuara', 'herminio', 'absirto', 'albuim', 'boiardo', 'ticiano', 'jack', 'quintilo', 'cleofas', 'geoffrey', 'wiltom', 'drew', 'lemoine', 'agron', 'krigor', 'konrad', 'dagomar', 'sedecias', 'anto', 'pero', 'bueno', 'airy', 'venerando', 'belamiro', 'dacio', 'damiao', 'eraldo', 'milan', 'hanibal', 'coimbra', 'icario', 'pirene', 'elson', 'cristovao', 'egido', 'aloisio', 'crispiano', 'oberico', 'eufrasio', 'tulio', 'juventino', 'jupiter', 'valeriana', 'jovino', 'marani', 'hoirandi', 'nei', 'sertorio', 'fayard', 'arantes', 'argos', 'epifanio', 'jose maria', 'arkell', 'eliu', 'jairo', 'nicolette', 'mucio', 'andre luiz', 'naama', 'newton', 'odir', 'riva', 'acelino', 'mazagoua', 'eliano', 'expedito', 'yannis', 'casto', 'garret', 'berengar', 'vespasiano', 'cesarino', 'ataide', 'petrarca', 'heneliaka', 'aderico', 'teixeira', 'haroldo', 'urias', 'menfis', 'perato', 'enrique', 'adel', 'hiran', 'palas', 'isaac', 'eudorico', 'roberval', 'paulo roberto', 'euro', 'ivan', 'curvelo', 'seleno', 'espedito', 'eric', 'haniel', 'bertario', 'raoul', 'zaniel', 'ipojuca', 'eulalio', 'caubi', 'hamilton', 'pascacio', 'relinde', 'gabriel henrique', 'antigowa', 'magnus', 'mario', 'caua', 'ganimedes', 'batimeu', 'evanildo', 'clistenes', 'dirceu', 'arion', 'geraldino', 'heraclito', 'nicacio', 'airon', 'tanuz', 'weston', 'wilmar', 'zebilon', 'estevam', 'goldman', 'amin', 'moritz', 'nicol', 'pancracio', 'janio', 'matteo', 'euler', 'tecoara', 'erik', 'arnobio', 'peterson', 'clarencio', 'eberaldo', 'ervino', 'euripedes', 'dwayne', 'chandler', 'lucio', 'etelvino', 'radagasio', 'kamal', 'albuquerque', 'dalberto', 'enoque', 'genilson', 'lorenzo', 'nycolas', 'ventura', 'gerardo', 'zachary', 'pergamo', 'stanley', 'narcisio', 'jabriel', 'alfred', 'dorval', 'germain', 'joaci', 'joao felipe', 'ladislau', 'leon', 'quevedo', 'rae', 'agatocles', 'schneider', 'gadi', 'odair', 'saulo', 'aldonca', 'alexandre', 'benoni', 'koma', 'nilsen', 'afif', 'adler', 'domiciano', 'aristocles', 'guilherme henrique', 'lalela', 'landim', 'laurence', 'osorio', 'ekewaka', 'plinio', 'balbino', 'amino', 'padovani', 'rozamondo', 'xandy', 'alirio', 'teodomiro', 'odilardo', 'ednei', 'jaire', 'tapiraca', 'robert', 'ederson', 'muniz', 'cadmo', 'luis henrique', 'anapio', 'charlie', 'galileu', 'fascinio', 'herminia', 'zarco', 'aimbere', 'azair', 'pires', 'valdomiro', 'goias', 'harold', 'ulpiano', 'itagiba', 'uziel', 'keith', 'elzeario', 'domenico', 'democrito', 'ifigenio', 'pieter', 'alcandro', 'valmir', 'mebahel', 'peresia', 'sarosh', 'tabajara', 'diocleciano', 'ichiro', 'isauro', 'balster', 'marceline', 'marco', 'lorrane', 'ondina', 'geraldo', 'daros' ...

# %%
# Out:
# cafe acougue a roma cao aaaa
